# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font color=#3BEBBC>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=ECC19C>
# آمار و احتمال مهندسی- دکتر نجفی
#             </font>
# 			<br />
# 			<br />
# بهار ۱۴۰۳
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=#ECC19C size=6>
# 			    <br />
# تمرین عملی
#             	<br/>
# 			</font>
# 		اعضای تمرین: پرهام رضایی - فرزام کوهی - محمدپیام تائبی - امیرحسین صوری - آسمانه نافع - اشکان مجیدی خامنه
# 			</br>
# 			<br>
# 			نام: آیدا جلالی
# 			<br>
# 			شماره دانشجویی: 401170542
#                 <br/><br/>
#                 <font color=#ECC19C>
#                  در فایل ارسالی تمام بلوک‌های کد باید اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند
# 								</font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %%
library("ggplot2")

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#3BEBBC size=6>
#         سوال اول - قانون اعداد بزرگ
#         </font>
#         </font>
#         <hr/>
#   </div>
#
#
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#   <font face="XB Zar" size=5>
# همانطور  که در کلاس آموختید با میل دادن $n$ به بی‌نهایت میانگین $n$ توزیع مستقل یکسان به امید ریاضی آن‌ها میل می‌کند. می‌خواهیم این موضوع را با نمونه برداری بررسی کنیم.
# </br>
#
#
# </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# میانگین ۱۰۰ نمونه از توزیع نمایی با پارامتر $\lambda = \frac{1}{10}$ را بدست آورید.
# </div>

# %%
lambda <- 1/10
samples <- rexp(100, rate = lambda)
average <- mean(samples)
cat(average)
# Out:
# 11.29985

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ب) (۱۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# حال میانگین را برای ۵۰۰۰ نمونه بدست آورید.
# </div>

# %%
lambda <- 1/10
samples <- rexp(5000, rate = lambda)
average <- mean(samples)
cat(average)
# Out:
# 10.30216

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#   با توجه به قانون اعداد بزرگ انتظار داریم با بزرگ شدن $n$ میانگین نزدیک به $\mathbb{E}[X]=\frac{۱}{\lambda}=۱۰$ بشود و همانطور که مشاهده می‌کنید خروجی قسمت ب) بسیار دقیق تر از قسمت الف) می‌باشد.
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     پ) (۱۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# اکنون نمودار همگرایی میانگین نمونه‌ها به امید ریاضی توزیع نمایی برحسب تعدادشان را برای $n=10000$ رسم‌ کنید.</br>
# <b>راهنمایی:</b> بردار زیر را تشکیل دهید:
# $$\left(
# \frac{x_۱}{۱}, \frac{x_۱ + x_۲}{۲}, \frac{x_۱+x_۲+x_۳}{۳},
# \frac{x_۱+x_۲+x_۳+x_۴}{۴}, \dots \right) .
# $$
# برای تشکل این بردار می‌توانید از تابع $\textrm{cumsum()}$ استفاده کنید.
# </div>

# %%
samples <- rexp(10000,1/10)
cumulative_sum <- cumsum(samples)
average <- cumulative_sum / seq_along(samples)
plot(average, type = "l", xlab = "N", ylab = "Average", main = "Convergence of Average to Expected Value")
abline(h = mean(samples), col = "red", lty = 2)
# Out:
# Plot with title “Convergence of Average to Expected Value”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# حال می‌خواهیم این نمودار را برای توزیع‌های دیگر نیز رسم کنیم و سرعت و دقت همگرایی آن‌ها را مشاهده کنیم. در سه بخش بعدی، این نمودار را برای توزیع های نرمال، پواسون و کوشی رسم خواهید کرد.
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ت) (۱۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# نمودار همگرایی را برای توزیع‌ نرمال با میانگین ۱۲ و واریانس ۵ رسم کنید.
# </div>

# %%
samples <- rnorm(10000, mean = 12, sd = 5)
cumulative_sum <- cumsum(samples)
average <- cumulative_sum / seq_along(samples)
plot(average, type = "l", xlab = "N", ylab = "Average", main = "Convergence of Average to Expected Value")
abline(h = mean(samples), col = "red", lty = 2)
# Out:
# Plot with title "Convergence of Average to Expected Value"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ث) (۱۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# نمودار همگرایی را برای توزیع پواسون با پارامتر ۱۰ رسم کنید.
# </div>

# %%
samples <- rpois(10000, 10)
cumulative_sum <- cumsum(samples)
average <- cumulative_sum / seq_along(samples)
plot(average, type = "l", xlab = "N", ylab = "Average", main = "Convergence of Average to Expected Value")
abline(h = mean(samples), col = "red", lty = 2)
# Out:
# Plot with title "Convergence of Average to Expected Value"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ج) (۲۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# نمودار همگرایی را برای توزیع‌ کوشی با $\gamma = ۱۰ , x_۰ =۰$ رسم کنید.
# </br>
# کدتان را چند بار اجرا کنید. چه تفاوتی بین این بخش و دو بخش قبل وجود دارد؟ توضیح دهید چرا این تفاوت وجود دارد؟ (نیاز به نوشتن معادلات نیست و توضیح دلیل نیز کافی می‌باشد)
# </div>

# %%
samples <- rcauchy(10000, 0,10)
cumulative_sum <- cumsum(samples)
average <- cumulative_sum / seq_along(samples)
plot(average, type = "l", xlab = "N", ylab = "Average", main = "Convergence of Average to Expected Value")
abline(h = mean(samples), col = "red", lty = 2)
# Out:
# Plot with title “Convergence of Average to Expected Value”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# توضیحات شما:
#
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE5533 size=3>
#
#          تفاوت اصلی که بین نمودار به دست آمده برای نمودار کوشی و نمودارهای دیگر وجود دارد به دلیل ویژگی های منحصر به فرد توزیع کوشی است.برخی از این ویژگی ها ماندد دم سنگین نمودار کوشی یا کمبود گشتاور متناهی که میتواند منجر به مشخصه های گسسته در نمودار به دست آمده شود یا حساسیت به outlier ها که  تاثیر زیادی بر دم نمودار کوشی میگذارد. در حالی که این ویژگی ها برای توزیع  های دیگر مانند توزیع نرمال و غیره وجود ندارد.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     چ) (۲۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# اکنون $m = ۴$ متغیر تصادفی مستقل از توزیع کوشی با $\gamma = ۱, x_۰ = ۰$ در نظر بگیرید. از هریک ۱۰۰۰ نمونه بردارید و یک بردار به طول ۱۰۰۰ از میانگین جفت‌های $m$ تایی آن‌ها تشکیل دهید. درنهایت هیستوگرام نمونه‌های به دست آمده را رسم کنید. همین کار را برای $m=۱۰$ نیز انجام دهید.
# </br>
# از مشاهدات خود چه نتیجه‌ای در مورد میانگین متغیرهای تصادفی از توزیع کوشی می‌گیرید؟
# </div>

# %%
n <- 1000
m <- 4
location <- 0
scale = 1
# TODO
samples <- matrix(rcauchy(m*n,location,scale),m)
average_samples <- rowMeans(samples)
hist(average_samples,breaks = 50 , col = 'skyblue' , border = 'black' ,xlab = 'Value' , ylab = 'Frequency' ,main = 'Average of 4 Cauchy R.V')

n <- 1000
location <- 0
m <- 10
samples <- matrix(rcauchy(m*n,location,scale),m)
average_samples <- rowMeans(samples)
hist(average_samples,breaks = 50 , col = 'skyblue' , border = 'black' ,xlab = 'Value' , ylab = 'Frequency' ,main = 'Average of 4 Cauchy R.V')

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# توضیحات شما:
# </br>
#
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE5533 size=4>
# میانگین متغیرهای تصادفی از توزیع کوشی وجود ندارد.
# <br>
# این به این دلیل است که توزیع کوشی، دم سنگین و واریانس نامتناهی دارد که به این دلیل است  که مقدارها به صورت گسترده ای باهم تفاوت دارند بنابراین میانگین تعریف نشده خواهد بود.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ح) (۱۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# داریم $X \sim \text{Exp}(0.1)$. با استفاده از قانون اعداد بزرگ تخمینی برای $\mathbb E[
# \log{\sqrt{X}}]
# $ بدست‌آورید و با توجه به قسمت‌های قبل با انتخاب تعداد نمونه برداری مناسب
#  دقت این تخمین را تا دهم اعشار تعیین کنید.
# </div>

# %%
lambda <- 0.1
samples <- rexp(100000, lambda)
estimate <- mean(log(sqrt(samples)))
cat("Estimation of E[log[sqrt[X]]]:", round(estimate,10))

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#3BEBBC size=6>
#          سوال دوم - فوتبال رنگارنگ
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
# محمدپیام این بار سر تمرین فوتبال آمده است. او به طور متوالی به سمت دروازه شوت می‌زند. اولین شوت او گل می‌شود ولی شوت بعدی را گل نمی‌کند.
#     از ضربه دوم به بعد به احتمال نسبت تعداد بارهایی که گل زده احتمال دارد که شوتش گل بشود.
#     برای مثال اگر تا شوت ۳۰ ام موفق شده باشد ۱۰ شوت را گل کند، به احتمال
# یک سوم شوت ۳۱ ام نیز گل خواهد شد.
# </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     <font color=#ECC19C>
# الف) (۸۰ نمره)
#     </font>
#     </br>
# صد ضربه اول محمدپیام را ۱۰۰۰۰ بار شبیه سازی کنید و
#             نمودار احتمال گل شدن i توپ از این صد ضربه را بر حسب مقادیر مختلف i، رسم کنید.
#             (۸۰ نمره)

# %%
# Set the number of simulations and shots
simulations <- 10000
shots <- 100

results <- matrix(0, nrow = simulations, ncol = shots)
outcomes <- c(0,1)
# Perform the simulations
for (i in 1:simulations) {
  results[i, 1] <- 1
  results[i, 2] <- 0
  score <- 1
  for (j in 3:shots) {
    prob_score <- (score / (j - 1))
    probs <- c((1-prob_score),prob_score)
    outcome <- sample(outcomes , size=1,prob=probs)
    results[i, j] <- outcome
    if (outcome == 1) {
      score <- score + 1
    }
  }
}

probabilities <- rowSums(results)

answer <- vector("numeric", length = 100)
for(i in 1:100)
{
    answer[i] = sum(probabilities == i)/ simulations
}
# Plot the graph
plot(1:100, answer, type = "p", xlab = "Number of Goals Scored", ylab = "Probability", main = "Probability of Scoring i Goals from 100 Shots")
# Out:
# Plot with title “Probability of Scoring i Goals from 100 Shots”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     <font color=#ECC19C>
# ب) (۱۰ نمره)
#     </font>
#     </br>
# با استفاده از نمودار بیان کنید احتمال اینکه دقیقا ۵۰ ضربه از ۱۰۰ ضربه اول گل بشود چه قدر هست؟

# %%
X <- 50
interpolated_value <- approx(1:shots,answer,xout = X)$y
cat("The probability that 50 goals scored from 100 shots is" , interpolated_value)
# Out:
# The probability that 50 goals scored from 100 shots is 0.0106

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     <font color=#ECC19C>
#     پ) (۱۰ نمره)
#     </font>
#     </br>
# نمودار به دست آمده از چه توزیعی پیروی میکند؟
# آیا احتمال گل شدن
# i ($1 \le i \lt n$)
# شوت از
# n
# شوت اول محمد پیام به
# i
# وابسته است؟
# به نظرتان با توجه به نمودار این مقدار چقدر است و با
#     n
#     چه نسبتی دارد؟

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE5533 size=4>
# نمودار به دست آمده از توزیع یکنواخت گسسته پیروی میکند.
# <br>
# چون توزیع یکنواخت گسسته است احتمال گل شدن i شوت به i وابسته نیست.
# <br>
# احتمال گل شدن i با n نسبت دارد.
# <br>
# تقریبا 0.01 است با توجه به نمودار ما
# <br>
# ratio of p(score) with n = 1/n

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     <font color=#ECC19C>
# ت)
#     </font>
#         آیا می توانید برای عددی که در قسمت قبل پیشنهاد دادید استدلال ریاضی نیز بیاورید؟
#         راهنمایی از استقرا روی n استفاده کنید.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#3BEBBC size=6>
#              سوال سوم -
#              کشاورزی، شغل انبیا!
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
# کشاورزی شغل بسیار سخت و طاقت فرسا و نیازمند به دقت زیاد است. فرض کنید در تولید محصول مشخصی، نیاز است که یک گیاه به میزان کافی در هر هفته آب دریافت کند. برای مثال فرض کنید میزان مناسب آب دریافتی گیاه ما در یک هفته بین 0.5 لیتر تا 2 لیتر است و اگر از این میزان کمتر یا بیشتر آب دریافت کند دچار خشکی یا پژمردگی می‌شود. مدت زمان رشد کامل این گیاه حدود 5 هفته است و در این 5 هفته، هر هفته باید همان میزان که گفته شد آب دریافت کند. فرض کنید میزان آب دریافتی گیاه در هر هفته از توزیع یکنواخت بین 0 تا 3 لیتر
# پیروی می‌کند.
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     الف) (۱۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#        در ابتدا ثابت کنید که هر میزان آب کمتر از 2.5 لیتر یا بیشتر از 10 لیتر موجب خشکی یا پژمردگی گیاه می شود.
#
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE553 size=5>
#
# میخواهیم اثبات کنیم هر میزان آب کمتر از ۲.۵ لیتر یا بیشتر از ۱۰ لیتر باعث خشکی یا پژمردگی گیاه میشود.
# میدانیم مقدار مناسب آب دریافتی توسط گیاه بین 0.5 لیتر تا 2 لیتر است.
# دوره رشد کامل گیاه حدود 5 است.
# علاوه بر این میدانیم مقدار آب دریافتی توسط گیاه هر هفته از توزیع یکنواخت پیروی میکند.
# مجموع مقدار آبی که گیاه برای ۵ هفته باید دریافت کند محاسبه میکنیم.
# هر مقدار کمتر یا بیشتر از این مقدار منجر به خشکی یا پژمردگی گیاه میشود.
#
# Minimum amount of Water = 5 weeks * 0.5 L = 2.5 L
#
# Maximum amount of Water = 5 weeks * 2 L = 10 L
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ب) (۳۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# آزمایش فوق را شبیه سازی کنید. (یعنی برای هر هفته یک عدد با توزیع یکنواخت برای میزان آب دریافتی داشته باشید و برای 5 هفته این کار را تکرار کنید و سالم ماندن یا نماندن گیاه بعد این 5 هفته را بررسی کنید.)
# </div>

# %%
# simulation for 1 time

water <- runif(5, min=0 , max=3)
total_water <- sum(water_received)
result <- numeric(0)

if (total_water >= 2.5 & total_water <= 10) {
    result <- 1  # healthy
}else{
    result <- 0  # not healthy
}
if(result == 1){
cat("plant remains healthy")
    }else{
    cat("plant doesn't remain healthy")
}
# Out:
# plant remains healthy

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#    پ) (۲۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# این آزمایش را به تعداد خوبی تکرار کنید و هیستوگرام میزان آب دریافتی گیاه را رسم کنید.  احتمال رشد سالم گیاه چقدر است؟
# </div>

# %%
number_of_simulations <- 100000
results <- numeric(number_of_simulations)
total_water_for_simulations <- numeric(number_of_simulations)

for (i in 1:number_of_simulations ) {

  water <- runif(5, min = 0, max = 3)
  total_water <- sum(water)
  total_water_for_simulations[i] <- total_water

  if (total_water >= 2.5 & total_water <= 10) {
    results[i] <- 1  #healthy
  } else {
    results[i] <- 0  #not healthy
  }
}
proportion_healthy <- mean(results)

#histogram
hist(total_water_for_simulations, breaks = 20, col = "skyblue", xlab = "Total Amount of Water Received", main = "Total Water Received by the Plant for 5 Weeks")
cat("Our plant remains healthy with this proportion: ", proportion_healthy, "\n")
# Out:
# Our plant remains healthy with this proportion:  0.89541
# Plot with title "Total Water Received by the Plant for 5 Weeks"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 	توجه:
# 	<br>
# برای دو بخش بعد، مقداری شرایط مسئله را ساده می‌کنیم. برای رشد سالم گیاه فقط لازم است کل میزان آب دریافتی از بازه بخش الف پیروی کند. دقت کنید که همچنان میزان آب دریافتی در هر هفته
# از توزیع یکنواخت بین 0 تا 3 لیتر
# پیروی می‌کند.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ت) (۲۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# فرض کنید کشاورز برای انجام یک تست، تعداد هفته ها را ۳، ۴ یا ۵ در نظر میگیرد و برای هر کدام از این تعداد هفته‌ها، از شما می‌خواهد آزمایش قبل را با تعریف جدید رشد سالم به تعداد زیاد تکرار کنید و در نهایت یک نمودار با استفاده از ggplot و geom_histogram رسم کنید که برای هر کدام از این تعداد هفته‌ها، رنگ میله‌ها متفاوت باشد. (راهنمایی: از "position = "dodge استفاده کنید.)
# </div>

# %%
library(ggplot2)

n <- c(3, 4, 5)
simulations <- 10000
weekly_water_hist <- list()
data <- data.frame()

for (w in n) {
  hstgrm <- matrix(nrow=w, ncol=simulations)
  for (i in 1:simulations) {
    every_week_water <- runif(w, min=0, max=3)
    hstgrm[, i] <- every_week_water
  }

  weekly_water_hist[[as.character(w)]] <- hstgrm
}

for (w in n) {
  temp <- data.frame(value = c(weekly_water_hist[[as.character(w)]]), w = as.factor(w))
  data <- rbind(data, temp)
}

ggplot(data = data, aes(x = value, fill = w)) +
  geom_histogram(binwidth = 1, alpha = 0.5, position = "dodge") +
  labs(title = "Water Received", x = "liters", y = "Frequency", fill = "n")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ث) (۲۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# احتمال سلامت رشد گیاه در هر کدام از این تعداد هفته ها را محاسبه کنید. احتمال کدام یک بیشتر است؟ چرا؟ (نیاز است در ابتدا توزیع آزمایش را پیدا کنید، اما تحلیل و محاسبه دقیق لازم نیست) دقت شود که محدوده مناسب آب دریافتی برای هر 3 نوع تعداد هفته، همان 2.5 تا 10 لیتر می‌باشد.
# </div>

# %%
plant_growth_probability <- function(number_of_weeks) {
number_of_simulations <- 100000
results <- numeric(number_of_simulations)
total_water_for_simulations <- numeric(number_of_simulations)

for (i in 1:number_of_simulations ) {

  water <- runif(number_of_weeks, min = 0, max = 3)
  total_water <- sum(water)
  total_water_for_simulations[i] <- total_water

  if (total_water >= 2.5 & total_water <= 10) {
    results[i] <- 1  #healthy
  } else {
    results[i] <- 0  #not healthy
  }
}
proportion_healthy <- mean(results)
    return(proportion_healthy)
}

cat("Our plant remains healthy with this proportion based on evert 3 weeks simulation: ", plant_growth_probability(3), "\n")
cat("Our plant remains healthy with this proportion based on evert 4 weeks simulation: ", plant_growth_probability(4), "\n")
cat("Our plant remains healthy with this proportion based on evert 5 weeks simulation: ", plant_growth_probability(5), "\n")
cat("Our plant remains healthy with highest probability for 4 weeks","\n")
# Out:
# Our plant remains healthy with this proportion based on evert 3 weeks simulation:  0.90355
# Our plant remains healthy with this proportion based on evert 4 weeks simulation:  0.97192
# Our plant remains healthy with this proportion based on evert 5 weeks simulation:  0.89435
# Our plant remains healthy with highest probability for 4 weeks

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE5533 size=3>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#3BEBBC size=6>
#              سوال چهارم - محمدپیام پرادعا
#         </font>
#         </font>
#         <hr/>
#   </div>
#
#
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#   <font face="XB Zar" size=5>
# محمدپیام پس از گذراندن درس آمار و احتمال مهندسی ادعای شدیدی در این درس پیدا کرده و فکر می‌کند از همه بهتر است. فرزام دانا برای این که روی محمدپیام را کم کند، سوالی به او می‌دهد تا حل کند. سوال فرزام این است که می‌خواهیم توزیعی برای طول و عرض نقاط بیابیم طوری که احتمال انتخاب نقاط $(x,y)$ درون یا روی دایره واحد به مرکز مبدا مختصات و شعاع واحد، برابر باشد و برای نقاط خارج از دایره این احتمال صفر باشد.</br>
# محمدپیام پس از این که چند روز درگیر حل این مسئله بود ادعا می‌کند آن را حل کرده و جوابش این است که $x$ و $y$ به ترتیب  به صورت یکنواخت در باز‌‌ه‌های $[-1, 1]$ و $[-\sqrt{1 - x^2}, \sqrt{1 - x^2}]$ قرار دارند اما قبل از این که پاسخ خود را به فرزام نشان دهد، پیش شما آمده تا از جواب خود مطمئن شود.
#
# </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     الف) (۱۸ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# برای درک بیشتر مسئله ۱۰۰۰۰ نمونه  $x$ و $y$ را تولید کنید، سپس با استفاده از این نمونه‌ها نمودار هیستوگرام را رسم کنید.
#
# </div>

# %%
samples <- 10000

x <- runif(samples, min = -1, max = 1)
y <- runif(samples, min = -sqrt(1 - x^2), max = sqrt(1 - x^2))

hist(x, breaks = 50, main = "x", xlab = "x", col = "skyblue", border = "black")
hist(y, breaks = 50, main = "y", xlab = "y", col = "skyblue", border = "black")
# Out:
# Plot with title "x"
# Plot with title "y"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ب) (۱۸ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# با استفاده از نمونه‌هایی که از $x$ و $y$ داریم، نقاط نمونه برداری شده درون دایره‌ی مسئله را مشخص کنید.
#
# </div>

# %%
plot(0, 0, type = "n", xlim = c(-1, 1), ylim = c(-1, 1), xlab = "x", ylab = "y", main = "Circle with Sampled Points")
draw.circle <- function(x, y, radius) {
  angles <- seq(0, 2 * pi, length.out = 10000)
  lines(x + radius * cos(angles), y + radius * sin(angles))
}
draw.circle(0, 0, radius)
points(x, y, col = "blue")
grid(lty = 10, col = "gray")
# Out:
# Plot with title "Circle with Sampled Points"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# با توجه به نمودار بالا و چگالی بیشتر نقاط در سمت راست و چپ دایره محمدپیام متوجه اشتباه خود شده و پس از چند ساعت فکر مجدد، به راه جدیدی می‌رسد:
# $$x=r\textrm{cos}(θ),y=r\textrm{cos}(θ)$$
# $r$ و $θ$ به ترتیب به صورت یکنواخت در بازه‌های $[0, 1]$ و $[-\pi, \pi]$ قرار دارند.
# حال او دوباره از شما می‌خواهد جوابش را بررسی کنید.
#
#
#   </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     پ) (۱۸ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# برای درک بیشتر مسئله ۱۰۰۰۰ نمونه  $x$ و $y$ را تولید کنید، سپس با استفاده از این نمونه‌ها نمودار هیستوگرام را رسم کنید.
# </div>

# %%
samples <- 10000

r <- runif(samples, min = 0, max = 1)
theta <- runif(samples, min = -pi, max = pi)

x <- r * cos(theta)
y <- r * sin(theta)

hist(x, breaks = 50, main = "x", xlab = "x", col = "skyblue", border = "black")
hist(y, breaks = 50, main = "y", xlab = "y", col = "skyblue", border = "black")
# Out:
# Plot with title "x"
# Plot with title "y"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ت) (۱۸ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# برای درک بیشتر مسئله ۱۰۰۰۰ نمونه  $x$ و $y$ را تولید کنید، سپس با استفاده از این نمونه‌ها نمودار هیستوگرام را رسم کنید.
# </div>

# %%
# TODO

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ث)  (۲۸ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# محمدپیام با دیدن نمودار متوجه اشتباه خود شد. او به شما قول داده درصورتی که به او در حل مسئله کمک کنید آدم متواضعی خواهد شد. برای کمک به محمدپیام حل درستی برای مسئله ارائه دهید.
#  در بخش زیر ابتدا توزیع $x$ و $y$ را ارائه دهید سپس با نمونه برداری از آن‌ها و کشیدن مکان آن‌ها درون دایره درستی ادعای خود را نشان دهید.
#
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# محل ارائه توضیحات:
#
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE5533 size=4>
#
#     با توجه به نمودار هیستوگرام x و y آن ها از نمودار گاوسی یا نرمال پیروی میکنند.
#     برای مشخص کردن x و y از مختصات قطبی استفاده میکنیم به طوری که شعاع ما شعاع واحد خواهد بود و زاویه بین pi و pi- تغییر میکند.
#     x^2 + y^2 <= 1
#     x = rcos(theta) , y = rsin(theta)
#     در قسمت بعدی با توجه به توزیع نرمال برای x و y دایره ای که در قسمت قبل کشیدیم را تصحیح میکنیم و متوجه میشویم تجمع نقاط بیشتر در مرکز دایره قرار دارد که با توجه به اینکه تراکم x و y هم هرکدام جداگانه بیشتر حول مرکز نمودار است منطقی به نظر میرسد.

# %%
samples <- 10000

r <- runif(samples, min = 0, max = 1)
theta <- runif(samples, min = -pi, max = pi)

x <- r * cos(theta)
y <- r * sin(theta)

plot(0, 0, type = "n", xlim = c(-1, 1), ylim = c(-1, 1), xlab = "x", ylab = "y", main = "Circle with Sampled Points")
draw.circle <- function(x, y, radius) {
  angles <- seq(0, 2 * pi, length.out = 10000)
  lines(x + radius * cos(angles), y + radius * sin(angles))
}
draw.circle(0, 0, radius)
points(x, y, col = "blue")
grid(lty = 10, col = "gray")
# Out:
# Plot with title "Circle with Sampled Points"

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#3BEBBC size=6>
#            سوال پنجم - بازی با مربع‌ها
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
#
# <font face="XB Zar" size=5>
# یک نوار افقی از $N+2$ مربع داریم که مربع اول و آخر آن سیاه هستند و مابقی $N$ مربع سفید رنگ اند. یک مربع سفید را به صورت یکنواخت به طور تصادفی انتخاب کرده، با احتمال یکسان یکی از دو همسایه‌اش را انتخاب می‌کنیم. اگر همسایه انتخاب شده هنوز سیاه نباشد، آن را به رنگ سیاه می‌کنیم. این فرآیند را تکرار می‌کنیم تا هیچ
# مربع سفیدی همسایه سفید نداشته باشد.
#  $w(N)$ را امیدریاضی تعداد مربع‌های سفید باقی‌مانده تعریف می‌کنیم. مقدار زیر را در نظر بگیرید:
# $$
# \lim _{N \rightarrow \infty} \frac{w(N)}{N}
# $$
# $$
# $$
# قصد داریم با استفاده از شبیه سازی این مقدار را  به دست بیاوریم. لطفا گام به گام موارد خواسته شده را پیاده سازی کنید تا در نهایت به جواب برسیم.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     الف) (۱۰۰ نمره)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#EE5533 size=3>
#   توجه
# سل های زیر برای آسودگی پیاده سازی شما نوشته شده اند. می‌توانید به جای پر کردن این سل ها از ابتدا خودتان شبیه سازی سوال را انجام داده و در صورت درستی نمره کامل دریافت کنید.
# </br>
# اگر چنین تصمیمی دارید، تمام سل های بخش الف این سوال را حذف نموده و کد خودتان را بنویسید.
# کد شما باید برای تعداد زیادی N
# با چندبار شبیه سازی این مقدار را شبیه سازی کرده و سپس حد به دست آمده را از روی نمودار تخمین بزنید.
# </br>
# در صورت وجود هر دو، نمره مینیمم به این بخش تخصیص می‌یابد.

# %%
# Load required library
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("ggplot2")

# %%
#DO NOT CHANGE ANYTHING IN THIS CELL.

test_simulate_step <- function() {
  # Test 1: One white square surrounded by black squares
  squares <- c(0, 1, 0, 0, 0)
  new_squares <- simulate_step(squares)
  # Expected result: One of the neighboring squares should become white
  if (any(new_squares == 0)) {
    print("Test 1 passed: One neighboring square turned white.")
  } else {
    print("Test 1 failed: No neighboring square turned white.")
  }

  # Test 2: Two white squares with one neighboring each
  squares <- c(0, 1, 0, 1, 0)
  new_squares <- simulate_step(squares)
  # Expected result: One of the neighboring squares should become white
  if (any(new_squares == 0)) {
    print("Test 2 passed: One neighboring square turned white.")
  } else {
    print("Test 2 failed: No neighboring square turned white.")
  }
}

test_check_adjacent_whites <- function() {
  # Test case 1: No white squares
  squares_1 <- c(1, 1, 1, 1, 1)
  if (check_adjacent_whites(squares_1)) {
    print("Test case 1 failed: No white squares")
  } else {
    print("Test case 1 passed")
  }

  # Test case 2: Single white square
  squares_2 <- c(1, 0, 1, 1, 1)
  if (check_adjacent_whites(squares_2)) {
    print("Test case 2 failed: Single white square")
  } else {
    print("Test case 2 passed")
  }

  # Test case 3: Adjacent white squares
  squares_3 <- c(1, 0, 0, 1, 1)
  if (check_adjacent_whites(squares_3)) {
    print("Test case 3 passed")
  } else {
    print("Test case 3 failed: Adjacent white squares")
  }

  # Test case 4: Non-adjacent white squares
  squares_4 <- c(1, 0, 1, 0, 1)
  if (check_adjacent_whites(squares_4)) {
    print("Test case 4 failed: Non-adjacent white squares")
  } else {
    print("Test case 4 passed")
  }
}



test_simulate_process <- function() {
  # Test 1: One white square surrounded by black squares
  N <- 3
  result <- simulate_process(N)
  # Expected result: 1/3, as one out of three squares remains white
  if (result == 1/3) {
    print("Test 1 passed: w(N)/N is correct.")
  } else {
    print("Test 1 failed: Incorrect w(N)/N value.")
  }

  # Test 2: Two white squares with one neighboring each
  N <- 4
  result <- simulate_process(N)
  # Expected result: 2/4, as two out of four squares remain white
  if (result == 2/4) {
    print("Test 2 passed: w(N)/N is correct.")
  } else {
    print("Test 2 failed: Incorrect w(N)/N value.")
  }
}

test_simulate_N_range <- function() {
  # Test: Simulation for N = 10, 20, 30 with 2 simulations each
  start_N <- 10
  end_N <- 30
  step_size <- 10
  num_simulations <- 2
  results <- simulate_N_range(start_N, end_N, step_size, num_simulations)
  # Expected result: Dataframe with 6 rows and 2 columns (N, w_N)
  if (nrow(results) == 6 && ncol(results) == 2) {
    print("Test passed: Correct number of rows and columns in results dataframe.")
  } else {
    print("Test failed: Unexpected number of rows or columns in results dataframe.")
  }
}

# %%
# Function to simulate one step of the process
simulate_step <- function(squares) {
  # TODO: Implement the logic to simulate one step of the process
  # 1. Identify the blocks  of white squares in the 'squares' vector.
  # 2. Determine if there are adjacent white squares.
  # 3. If there are adjacent white squares, choose a random white square.
  # 4. Change the color of one of its neighboring squares to white.
  # 5. Return the updated 'squares' vector
    random_rng <- runif(1, 0, 1)
    current_block <-0
    blocks <-which(squares == 0)
    sampled <- sample(blocks ,1)
    L <- length(squares)
    if(sampled==1){
      current_block  <-2
    }
    else if(random_rng <= 0.5){
      current_block  <- (sampled - 1)
    }
    else if(L == sampled){
      current_block  <- (L -1)
    }
    else{current_block  <- (sampled + 1)
    }
    if(squares[current_block ] == 0){
      squares[current_block ]<- 1}
    return(squares)
}

# %%
test_simulate_step()
# Out:
# [1] "Test 1 passed: One neighboring square turned white."
# [1] "Test 2 passed: One neighboring square turned white."

# %%
# Function to check if there are adjacent white_area squares left
check_adjacent_whites <- function(squares) {
    # TODO: Implement the logic to check if there are adjacent white_area squares left
  # 1. Identify the indices of white_area squares in the 'squares' vector.
  # 2. If there are fewer than two white_area squares, return FALSE.
  # 3. Otherwise, check if there are adjacent white_area squares.
  # 4. Return TRUE if there are adjacent white_area squares, otherwise return FALSE.
  white_area <- which(squares == 0)
  reverse_l = -length(white_area);
  for (i in seq_along(white_area)[reverse_l]) {
    delta = white_area[i + 1] - white_area[i]
    if (delta == 1) {
      return(TRUE)
    }
  }
  return(FALSE)
}

# %%
test_check_adjacent_whites()
# Out:
# [1] "Test case 1 passed"
# [1] "Test case 2 passed"
# [1] "Test case 3 passed"
# [1] "Test case 4 passed"

# %%
# Function to simulate the process and calculate w(N)/N
simulate_process <- function(N) { # 20 Points
  # TODO: Implement the logic to simulate the process and calculate w(N)/N
  # 1. Initialize the 'squares' vector with one white square at each end and N black squares in between.
  # 2. While there are adjacent white squares:
  #    a. Simulate one step of the process using the 'simulate_step' function.
  # 3. Count the number of remaining white squares.
  # 4. Calculate w(N)/N as the ratio of remaining white squares to the total number of squares (N).
  # 5. Return w(N)/N.
 squares <- c(1, rep(0, N), 1)

  while(check_adjacent_whites(squares))
    squares<-simulate_step(squares)

  w<- length(which(squares==0))

  return (w/N)
}

# %%
test_simulate_process()
# Out:
# [1] "Test 1 passed: w(N)/N is correct."
# [1] "Test 2 passed: w(N)/N is correct."

# %%
# Function to perform simulations for a range of N values
simulate_N_range <- function(start_N, end_N, step_size, num_simulations) { # 20 Points
  # TODO: Implement the logic to perform simulations for a range of N values
  # 1. Initialize an empty dataframe 'results' to store simulation results.
  # 2. Calculate the total number of simulations to be performed.
  # 3. Loop through a range of N values from 'start_N' to 'end_N' with a step size of 'step_size':
  #    a. For each N value, loop 'num_simulations' times:
  #       i. Simulate the process using the 'simulate_process' function.
  #       ii. Store the N value and w(N)/N in the 'results' dataframe.
  #       iii. Update the progress indicator to track the completion percentage.
  # 4. Return the 'results' dataframe containing simulation results.
  results <- data.frame(
    k = numeric(),
    bonus = numeric()
  )
  for (i in seq(start_N, end_N, step_size)){
    for(j in 1:num_simulations){
      results <- rbind(results, data.frame(k = i, bonus = simulate_process(i)))
    }
  }
  return (results)
}

# %%
test_simulate_N_range()
# Out:
# [1] "Test passed: Correct number of rows and columns in results dataframe."

# %%
plot_results <- function(results) {
  library(ggplot2)
  # 20 Points
  # TODO: Implement the logic to plot the results
  # 1. Create a scatter plot using ggplot with N on the x-axis and w(N)/N on the y-axis.
  # 2. Add a smooth trend line to the plot.
  # 3. Set appropriate labels for the plot title, x-axis, and y-axis.
  # 4. Apply a minimal theme to the plot.
  # 5. Return the ggplot object.
  p<-ggplot(results,aes(nValue,rate))+
    geom_point()+
    ggtitle("N & w(N)/N" comparison)+xlab("N")+ylab("w(N)/N")
  return (p)
}

# %%
main <- function(start_N, end_N, step_size, num_simulations) {
  # Save the true value of 1/e
  true_value <- 1 / exp(1)

  # Perform simulations for a range of N values
  results <- simulate_N_range(start_N, end_N, step_size, num_simulations)

  # Calculate the mean of the calculated values
  mean_calculated_value <- mean(results$w_N)

  # Print the calculated value, true value, and absolute error
  cat("Calculated Value: ", mean_calculated_value, "\n")
  cat("True Value (1/e): ", true_value, "\n")
  cat("Absolute Error: ", abs(mean_calculated_value - true_value), "\n")

  # Plot the results
  plot_results(results)
}

# %%
main(10, 3000, 50, 5)
# Out:
# Calculated Value:  0.3688286
# True Value (1/e):  0.3678794
# Absolute Error:  0.0009491377
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#  حال
#   می‌خواهیم سوال را به صورت تئوری نیز حل کنیم.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     ب)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ابتدا احتمال سیاه شدن هر مربع را در اولین حرکت بیابید.
# (این احتمال برای مربع ۲ام و N+1 ام
# با بقیه متفاوت است)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#     پ)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# اگر دقت کنید بعد از حرکت اول و سیاه شدن مربع برای مثال iام
# مسئله به دو نوار ۱ تا i
# و i
# تا N+2
# که هر دو ابتدا و انتهای سیاه دارند تبدیل شده است.
# با استفاده از این نگاه یک رابطه بازگشتی برای
# $w(N)$
# به دست بیاورید.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#    ت)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# با استفاده از رابطه بازگشتی‌ای که به دست آوردید و به کمک استقرا ثابت کنید که
# برای $N\geq 0$
# $$w(N) = (N+1)\sum_{k=0}^{N+1}\frac{(-1)^k}{k!}$$

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" color=#ECC19C size=5>
#    ث)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# حال به کمک عبارت بخش قبل و توجه به سری تیلور، حد مدنظر سوال را به دست بیاورید.
